# %% [markdown]
# # Assignment 3

# %% [markdown]
# You only need to write one line of code for each question. When answering questions that ask you to identify or interpret something, the length of your response doesn’t matter. For example, if the answer is just ‘yes,’ ‘no,’ or a number, you can just give that answer without adding anything else.
#
# We will go through comparable code and concepts in the live learning session. If you run into trouble, start by using the help `help()` function in Python, to get information about the datasets and function in question. The internet is also a great resource when coding (though note that **no outside searches are required by the assignment!**). If you do incorporate code from the internet, please cite the source within your code (providing a URL is sufficient).
#
# Please bring questions that you cannot work out on your own to office hours, work periods or share with your peers on Slack. We will work with you through the issue.

# %% [markdown]
# ### Clustering and Resampling
#
# Let's set up our workspace and use the **Iris dataset** from `scikit-learn`. This dataset is a classic dataset in machine learning and statistics, widely used for clustering tasks. It consists of many samples of iris flowers. Here are the key features and characteristics of the dataset:
#
# ##### Features:
# 1. **Sepal Length**: The length of the sepal in centimeters.
# 2. **Sepal Width**: The width of the sepal in centimeters.
# 3. **Petal Length**: The length of the petal in centimeters.
# 4. **Petal Width**: The width of the petal in centimeters.

# %%
# Import standard libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans

# %% [markdown]
# #### **Question 1:**
# #### Data inspection
#
# #### Load the Iris dataset:
#
# Use scikit-learn to load the Iris dataset and convert it into a Pandas DataFrame.
# Display the first few rows of the dataset. How many observations (rows) and features (columns) does the dataset contain?

# %%
from sklearn.datasets import load_iris
# Load the Iris dataset
iris_data = load_iris()

# Convert to DataFrame
iris_df = pd.DataFrame(iris_data.data, columns=iris_data.feature_names)

# Display the DataFrame
print(iris_df)

# Your code here...


print(
    "The iris_df dataset contains", iris_df.shape[0], "observations (rows) and", iris_df.shape[1], "features (columns)."
)
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
# [150 rows x 4 columns]
# The iris_df dataset contains 150 observations (rows) and 4 features (columns).

# %% [markdown]
# #### **Question 2:**
# #### Data-visualization
#
# Let's create plots to visualize the relationships between the features (sepal length, sepal width, petal length, petal width).

# %%
def plot_feature_pairs(data, feature_names, color_labels=None, title_prefix=''):
    """
    Helper function to create scatter plots for all possible pairs of features.
    
    Parameters:
    - data: DataFrame containing the features to be plotted.
    - feature_names: List of feature names to be used in plotting.
    - color_labels: Optional. Cluster or class labels to color the scatter plots.
    - title_prefix: Optional. Prefix for plot titles to distinguish between different sets of plots.
    """
    # Create a figure for the scatter plots
    plt.figure(figsize=(12, 10))
    
    # Counter for subplot index
    plot_number = 1
    
    # Loop through each pair of features
    for i in range(len(feature_names)):
        for j in range(i + 1, len(feature_names)):
            plt.subplot(len(feature_names)-1, len(feature_names)-1, plot_number)
            
            # Scatter plot colored by labels if provided
            if color_labels is not None:
                plt.scatter(data[feature_names[i]], data[feature_names[j]], 
                            c=color_labels, cmap='viridis', alpha=0.7)
            else:
                plt.scatter(data[feature_names[i]], data[feature_names[j]], alpha=0.7)
            
            plt.xlabel(feature_names[i])
            plt.ylabel(feature_names[j])
            plt.title(f'{title_prefix}{feature_names[i]} vs {feature_names[j]}')
            
            # Increment the plot number
            plot_number += 1

    # Adjust layout to prevent overlap
    plt.tight_layout()

    # Show the plot
    plt.show()


# Get feature names
feature_names = iris_df.columns

# Use the helper function to plot scatter plots without coloring by cluster labels
plot_feature_pairs(iris_df, feature_names, title_prefix='Original Data: ')

# %% [markdown]
# **Question:**
# - Do you notice any patterns or relationships between the different features? How might these patterns help in distinguishing between different species?

# %% [markdown]
# > In each pairwise comparison it seems like there are two distinct groups or characteristics. This may help in distinguishing the number of groups to pick in our cluster analysis.

# %% [markdown]
# #### **Question 3:**
# #### Data cleaning

# %%
# Initialize the StandardScaler
scaler = StandardScaler()

# Scale all the features in the dataset
scaled_features = scaler.fit_transform(iris_df)

# Create a new DataFrame with scaled features
scaled_iris_df = pd.DataFrame(scaled_features, columns=iris_data.feature_names)

# Display the first few rows of the scaled DataFrame
print(scaled_iris_df.head())
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0          -0.900681          1.019004          -1.340227         -1.315444
# 1          -1.143017         -0.131979          -1.340227         -1.315444
# 2          -1.385353          0.328414          -1.397064         -1.315444
# 3          -1.506521          0.098217          -1.283389         -1.315444
# 4          -1.021849          1.249201          -1.340227         -1.315444

# %% [markdown]
# Why is it important to standardize the features of a dataset before applying clustering algorithms like K-Means? Discuss the implications of using unstandardized data in your analysis.

# %% [markdown]
# >Based on text book Data Science - A First Introduction page 302: K-meas clusting uses straight line distance to determine which points are similar to each other. As such, the scale of each variable will influence which clluster data points actually get assigned. Variables with a larger scale will have a larger impact on determining cluster assignment versus variables with a smaller scale. Therefore, we standardize the data before clustering to ensure each variable has a mean of 0 and standard deviation of 1.

# %% [markdown]
# #### **Question 4:**
# #### K-means clustering
#
# Apply the K-Means clustering algorithm to the Iris dataset. Choose the value 3 for the number of clusters (`k=3`) and fit the model. Assign cluster labels to the original data and add them as a new column in the DataFrame.

# %%
# Load iris dataset
iris_data = load_iris()

# Create a DataFrame from the dataset
iris_df = pd.DataFrame(iris_data.data, columns=iris_data.feature_names)

# Add species column
iris_df['species'] = pd.Categorical.from_codes(iris_data.target, iris_data.target_names)

# Set random seed
random_seed = 42

# Standardizing features
scaler = StandardScaler()

# Ensure 'species' exists and drop it only for the features to be standardized
iris_features = iris_df.drop("species", axis=1)

# Standardize the features
iris_standardized = scaler.fit_transform(iris_features)

# Fit KMeans
kmeans = KMeans(n_clusters=3, random_state=random_seed)
iris_df['Cluster'] = kmeans.fit_predict(iris_standardized)

# Create a copy of the DataFrame with clusters
clustered_iris_data_1 = iris_df.copy()

# Get feature names (ensure only feature columns are included)
feature_names = iris_df.columns[:-2]  # Exclude 'species' and 'Cluster' columns



# Plot clustered data
plot_feature_pairs(clustered_iris_data_1, feature_names, 
                  color_labels=clustered_iris_data_1['Cluster'], 
                  title_prefix='Clustered Data: ')

# %%
# Perform K-means clustering
kmeans = KMeans(n_clusters=3, random_state=0)
clusters = kmeans.fit(scaled_iris_df)

# Create a copy of the DataFrame for clustering and modification
scaled_iris_with_clusters = scaled_iris_df.copy()

# Add cluster labels to the copied DataFrame
scaled_iris_with_clusters['Cluster'] = clusters.labels_

# Display the updated DataFrame with the 'Cluster' column
scaled_iris_with_clusters

clustered_iris_data_2= scaled_iris_with_clusters


# Use the helper function to plot scatter plots, colored by cluster labels
plot_feature_pairs(clustered_iris_data_2, feature_names, color_labels=clustered_iris_data_2['Cluster'], title_prefix='Clustered Data: ')

# %%
# Compare the two clustering results
print("Comparison of two clustering approaches:")
comparison = pd.crosstab(clustered_iris_data_1['Cluster'], 
                        clustered_iris_data_2['Cluster'],
                        margins=True)
print("\nCross-tabulation of Cluster Assignments:")
print(comparison)

# Compare cluster means
print("\nFirst approach cluster means:")
print(clustered_iris_data_1.groupby('Cluster')[feature_names].mean())

print("\nSecond approach cluster means:")
print(clustered_iris_data_2.groupby('Cluster')[feature_names].mean())

# Visualize the differences
plt.figure(figsize=(15, 5))

# Plot first approach
plt.subplot(1, 2, 1)
plt.scatter(clustered_iris_data_1[feature_names[0]], 
           clustered_iris_data_1[feature_names[1]], 
           c=clustered_iris_data_1['Cluster'],
           cmap='viridis')
plt.title('First Approach Clustering')
plt.xlabel(feature_names[0])
plt.ylabel(feature_names[1])

# Plot second approach
plt.subplot(1, 2, 2)
plt.scatter(clustered_iris_data_2[feature_names[0]], 
           clustered_iris_data_2[feature_names[1]], 
           c=clustered_iris_data_2['Cluster'],
           cmap='viridis')
plt.title('Second Approach Clustering')
plt.xlabel(feature_names[0])
plt.ylabel(feature_names[1])

plt.tight_layout()
plt.show()
# Out:
# Comparison of two clustering approaches:
#
# Cross-tabulation of Cluster Assignments:
# Cluster   0   1   2  All
# Cluster
# 0        45   0  51   96
# 1         0  33   0   33
# 2         4  17   0   21
# All      49  50  51  150
#
# First approach cluster means:
#          sepal length (cm)  sepal width (cm)  petal length (cm)  \
# Cluster
# 0                 6.314583          2.895833           4.973958
# 1                 5.169697          3.630303           1.493939
# 2                 4.747619          2.895238           1.757143
#
#          petal width (cm)
# Cluster
# 0                1.703125
# 1                0.272727
# 2                0.352381
#
# Second approach cluster means:
#          sepal length (cm)  sepal width (cm)  petal length (cm)  \
# Cluster
# 0                -0.077234         -0.930621           0.323138
# 1                -1.014579          0.853263          -1.304987
# 2                 1.068891          0.057594           0.968933
#
#          petal width (cm)
# Cluster
# 0                0.237278
# 1               -1.254893
# 2                1.002315

# %% [markdown]
# We chose `k=3` for the number of clusters arbitrarily. However, in a real-world scenario, it is important to determine the optimal number of clusters using appropriate methods.
#
# **Question**: What is one method commonly used to determine the optimal number of clusters in K-means clustering, and why is this method helpful?

# %% [markdown]
# > based on text book Data Science - A First Introduction page 300: You can use the elbow method to choose value of K (number of clusters). If you plot the total WSSD (within cluster sum of squared distance), it shows how the total decrease in WSSD levels off (makes an elbow shape) when we reach the right number of clusters to select.

# %% [markdown]
# #### **Question 5:**
# #### Bootstrapping
#
# Implement bootstrapping on the mean of Petal Width. Generate 10000 bootstrap samples, calculate the mean for each sample, and compute a 90% confidence interval.

# %%
# Your answer here...
petal_width = iris_df['petal width (cm)']
n_samples = 10000
bootstrap_means = [np.mean(np.random.choice(petal_width, size=len(petal_width), replace=True)) for _ in range(n_samples)]

mean_petal_width = np.mean(petal_width)

np.random.seed(123)

lower_bound = np.percentile(bootstrap_means, 5)
upper_bound = np.percentile(bootstrap_means, 95)



# Display the result
print(f"Mean of Petal Width: {mean_petal_width}")
print(f"90% Confidence Interval of Mean Petal Width: ({lower_bound}, {upper_bound})")
# Out:
# Mean of Petal Width: 1.1993333333333336
# 90% Confidence Interval of Mean Petal Width: (1.0979666666666665, 1.302)

# %% [markdown]
# **Question:**
# - Why do we use bootstrapping in this context? What does it help us understand about the mean?

# %% [markdown]
# >  based on text book Data Science - A First Introduction page 332: We use bootstapping because we have just one smaple from our population (we don't have access to the full population itself). As such, we need to approximate what the sampling distribution would look like for the sample and then use that approximation to report the uncertainty of the sample point estimate. We are estimating the distribution of the mean by repeatedly sampling from the data with replacement, to understand the sampling variability of the mean of the sepal_length feature from the Iris datas.

# %% [markdown]
# **Question:**
# - What is the purpose of calculating the confidence interval from the bootstrap samples? How does it help us interpret the variability of the estimate?

# %% [markdown]
# > based on text book Data Science - A First Introduction page 332: confidence interval - the range of plausible values for the population parameter It helps us assess the uncertainty and variability of the estimate by giving a range within which the true population parameter is likely to fall The confidence interval of (5.72 cm, 5.98 cm) for the mean sepal length suggests that the true mean is likely to fall within this range, which tells us how much uncertainty there is around the sample mean of 5.84 cm.

# %% [markdown]
# **Question:**
#
# - Reflect on the variability observed in the bootstrapped means and discuss whether the mean of the Petal Width appears to be a stable and reliable estimate based on the confidence interval and the spread of the bootstrapped means.

# %% [markdown]
# > The variability in the bootstrapped means is relatively small with maybe 1 standard deviation approximately 0.1 cm around the mean petal width. The 90% confidence interval is also relatively narrow so the mean of the petal width does appear to be a stable and reliable estimate.

# %% [markdown]
# # Criteria
#
#
# | **Criteria**                                           | **Complete**                                      | **Incomplete**                                    |
# |--------------------------------------------------------|---------------------------------------------------|--------------------------------------------------|
# | **Data Inspection**                                    | Data is thoroughly inspected for the number of variables, observations, and data types, and relevant insights are noted. | Data inspection is missing or lacks detail.         |
# | **Data Visualization**                                 | Visualizations (e.g., scatter plots) are well-constructed and correctly interpreted to explore relationships between features and species. | Visualizations are poorly constructed or not correctly interpreted. |
# | **Clustering Implementation**                           | K-Means clustering is correctly implemented, and cluster labels are appropriately assigned to the dataset.            | K-Means clustering is missing or incorrectly implemented. |
# | **Bootstrapping Process**                              | Bootstrapping is correctly performed, and results are used to assess variable mean stability. | Bootstrapping is missing or incorrectly performed. |

# %% [markdown]
# ## Submission Information
#
# 🚨 **Please review our [Assignment Submission Guide](https://github.com/UofT-DSI/onboarding/blob/main/onboarding_documents/submissions.md)** 🚨 for detailed instructions on how to format, branch, and submit your work. Following these guidelines is crucial for your submissions to be evaluated correctly.
#
# ### Note:
#
# If you like, you may collaborate with others in the cohort. If you choose to do so, please indicate with whom you have worked with in your pull request by tagging their GitHub username. Separate submissions are required.
#
# ### Submission Parameters:
# * Submission Due Date: `11:59 PM - 01/26/2025`
# * The branch name for your repo should be: `assignment-3`
# * What to submit for this assignment:
#     * This Jupyter Notebook (assignment_1.ipynb) should be populated and should be the only change in your pull request.
# * What the pull request link should look like for this assignment: `https://github.com/<your_github_username>/LCR/pull/<pr_id>`
#     * Open a private window in your browser. Copy and paste the link to your pull request into the address bar. Make sure you can see your pull request properly. This helps the technical facilitator and learning support staff review your submission easily.
#
# Checklist:
# - [x] Created a branch with the correct naming convention.
# - [x] Ensured that the repository is public.
# - [x] Reviewed the PR description guidelines and adhered to them.
# - [x] Verify that the link is accessible in a private browser window.
#
# If you encounter any difficulties or have questions, please don't hesitate to reach out to our team via our Slack at `#cohort-4-help`. Our Technical Facilitators and Learning Support staff are here to help you navigate any challenges.
